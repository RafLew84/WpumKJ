// %% [markdown]
// # Lista 4
//
// ## Zad 1 - **1 pkt**
//
// Napisz funcję lambda przyjmującą `s:String, i:Int` i zwracającą `String` zawierający `i` kopii `s`
//
// input:<br>
// `("a", 3)`
//
// output:<br>
// `aaa`
//
// ## Zad 2 - **1 pkt**
//
// Przepisz<br>
// `val f : (String) -> String = { s:String -> s + "!" }`<br>
// wykorzysując `it`
//
// ## Zad 3 - **1 pkt**
//
// Napisz funkcję `fun fib(i: Int): Int` z wykorzystaniem funkcji lokalnej z modyfikatorem `tailrec` zwracającą n-ty wyraz ciągu Fibonacci'ego
//
// ## Zad 4 - **1 pkt**
//
// Napisz funkcję `fun log2(i: Int): Int` z wykorzystaniem funkcji lokalnej zwracającą log<sub>2</sub>( i )
//
// ## Zad 5 - **1 pkt**
//
// Napisz funkcję wyższego rzędu formatującą wynik funkcji z zadań 3 i 4.<br>
// `fun formatResult(name: String, n: Int, f: (Int) -> Int): String `
//
// ## Zad 6 - **1 pkt**
//
// Zaimplementuj właściwości rozszerzające:<br>
// - `val <T> List<T>.tail: List<T>` zwracającą listę wszystkich elementów listy oprócz pierwszego
// - `val <T> List<T>.head: T` zwracającą pierwszy element listy
//
// ## Zad 7 - **2 pkt**
//
// Zaimplementuj funkcję `isSorted(aa: List<A>, order: (A, A) -> Boolean): Boolean` sprawdzającą czy lista `List<A>` jest posortowana zgodnie z funkcją porównawczą.
//
// Przykładowo:<br>
// <code>isSorted(listOf(1, 2, 3, 4), {i: Int, j: Int -> i < j})
// true</code>
//
// `isSorted(listOf(1, 1, 1, 1), {i: Int, j: Int -> i==j})`<br>
// `true`<br>
//
// `isSorted(listOf("ahyyhh", "bkjn", "cnn", "duu"), {i: String, j: String -> i.first() < j.first()})`<br>
// `true`
//
// ## Zad 8 - **1 pkt**
//
// Napisz funkcję `suma(a: Array<Int>): Int` zwracającą sumę wszystkich dodatnich liczb w liście (wykorzystaj funkcje `map`, `filter`, `reduce` ...)
//
// input = \[ 1, -4, 12, 0, -3, 29, -150\]<br>
// output = 42
//
// ## Zad 9 - **1 pkt**
//
// Napisz funkcję `countElements` przyjmującą tablicę i zwracającą mapę zawierającą liczbę wystąpień każdego elemetu. Funkcja powinna działać na tablicy tablic.
//
// <code>
// input = [
//     ['a', 'b', 'c'],
//     ['c', 'd', 'f'],
//     ['d', 'f', 'g']
//   ]
// </code>
//
// <code>
// output =
//   {
//     a: 1,
//     b: 1,
//     c: 2,
//     d: 2,
//     f: 2,
//     g: 1
//   }
// </code>

// %% [markdown]
// ### Oceny
//
// |**ocena**|**punkty**|
// |:---:|:---:|
// |3,0 | 6 pkt|
// |3,5 | 7 pkt|
// |4,0 | 8 pkt|
// |4,5 | 9 pkt|
// |5,0 | 10 pkt|
